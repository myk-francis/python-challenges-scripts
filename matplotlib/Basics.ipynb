# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
x = np.arange(0, 100)
y = x * 2
z = x ** 2

# %%
# Functional
plt.plot(x, y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r')

plt.subplot(1, 2, 2)
plt.plot(y, x, 'b')

# %%
#OBJECT ORIENTED
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x, y)
axes1.set_title('LARGER PLOT')
axes2.plot(y, x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x,y)
ax.set_title('Title')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.3, 0.3])
ax1.plot(x, y, color='red')
ax2.plot(x,y, color='red')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])

ax1.plot(x, z, color='blue')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.plot(x, y, color='blue')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Zoom')
ax2.set_xlim(20, 22)
ax2.set_ylim(30, 50)
# Out:
# (30.0, 50.0)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (12, 2))

axes[0].plot(x, y, color='blue', lw=3, ls='--') 
axes[1].plot(x, z, color='red', lw=3, ls='-')

# %%
mcdon = pd.read_csv('mcdonalds.csv', index_col='Date', parse_dates=True)
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon['Adj. Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
mcdon['Adj. Volume'].plot(figsize=(12, 4))
# Out:
# <Axes: xlabel='Date'>

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'], ylim=[20, 50])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axis.py:1736, in Axis.convert_units(self, x)
#    1735 try:
# -> 1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a pandas._libs.tslibs.timestamps.Timestamp
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'], ylim=[20, 50])
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:455, in MPLPlot.generate(self)
#     453 self._add_table()
#     454 self._make_legend()
# --> 455 self._adorn_subplots()
#     457 for ax in self.axes:
#     458     self._post_plot_logic_common(ax, self.data)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:701, in MPLPlot._adorn_subplots(self)
#     698     ax.set_ylim(self.ylim)
#     700 if self.xlim is not None:
# --> 701     ax.set_xlim(self.xlim)
#     703 # GH9093, currently Pandas does not show ylabel, so if users provide
#     704 # ylabel will set it as ylabel in the plot.
#     705 if self.ylabel is not None:
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3652, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3650         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3651     right = xmax
# -> 3652 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axis.py:1178, in Axis._set_lim(self, v0, v1, emit, auto)
#    1158 """
#    1159 Set view limits.
#    1160
#    (...)
#    1173     turns off, None leaves unchanged.
#    1174 """
#    1175 name, = [name for name, axis in self.axes._axis_map.items()
#    1176          if axis is self]  # The axis name.
# -> 1178 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
#    1179 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1180 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2551, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if (axis is not None and
#    2549             data is not None and
#    2550             not axis._have_units_and_converter()):
# -> 2551         axis.update_units(data)
#    2552 for axis_name, axis in axis_map.items():
#    2553     # Return if no axis is set.
#    2554     if axis is None:
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axis.py:1670, in Axis.update_units(self, data)
#    1668 neednew = self.converter != converter
#    1669 self.converter = converter
# -> 1670 default = self.converter.default_units(data, self)
#    1671 if default is not None and self.units is None:
#    1672     self.set_units(default)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axis.py:1768, in Axis.set_units(self, u)
#    1766 axis.units = u
#    1767 axis._update_axisinfo()
# -> 1768 axis.callbacks.process('units')
#    1769 axis.stale = True
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2455, in _AxesBase._unit_change_handler(self, axis_name, event)
#    2453 _api.check_in_list(self._axis_map, axis_name=axis_name)
#    2454 for line in self.lines:
# -> 2455     line.recache_always()
#    2456 self.relim()
#    2457 self._request_autoscale_view(axis_name)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\lines.py:652, in Line2D.recache_always(self)
#     651 def recache_always(self):
# --> 652     self.recache(always=True)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\lines.py:656, in Line2D.recache(self, always)
#     654 def recache(self, always=False):
#     655     if always or self._invalidx:
# --> 656         xconv = self.convert_xunits(self._xorig)
#     657         x = _to_unmasked_float_array(xconv).ravel()
#     658     else:
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\artist.py:281, in Artist.convert_xunits(self, x)
#     279 if ax is None or ax.xaxis is None:
#     280     return x
# --> 281 return ax.xaxis.convert_units(x)
#
# File c:\Users\HP\anaconda3\lib\site-packages\matplotlib\axis.py:1738, in Axis.convert_units(self, x)
#    1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
# -> 1738     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1739                                  f'units: {x!r}') from e
#    1740 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array([Timestamp('1970-01-02 00:00:00'), Timestamp('1970-01-05 00:00:00'),
#        Timestamp('1970-01-06 00:00:00'), ...,
#        Timestamp('2017-07-12 00:00:00'), Timestamp('2017-07-13 00:00:00'),
#        Timestamp('2017-07-14 00:00:00')], dtype=object)

# %%
df3 = pd.read_csv('df3')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a', y='b', c='red', s=50, figsize=(12, 3))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df3['a'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
df3['a'].hist(bins=25)
# Out:
# <Axes: >

# %%
df3[['a', 'b']].plot.box()
# Out:
# <Axes: >

# %%
df3[['a', 'b']].head()
# Out:
#           a         b
# 0  0.336272  0.325011
# 1  0.980265  0.831835
# 2  0.480387  0.686839
# 3  0.502106  0.305142
# 4  0.856602  0.171448

# %%
df3['d'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df3['d'].plot.density(lw=5, ls='--')
# Out:
# <Axes: ylabel='Density'>

# %%
f =  plt.figure()
df3.iloc[0:30].plot.area(alpha=0.4)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
